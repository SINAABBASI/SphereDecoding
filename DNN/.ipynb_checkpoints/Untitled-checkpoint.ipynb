# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df_train = pd.read_csv('data.csv', index_col=0)
df_train.head()
# Out:
#            x0         x1         x2         x3         x4         x5  \
# id
# 1  -13.675028  -1.378920  -7.348755 -25.012276 -18.301566  -9.112121
# 2    8.599901  -2.831504 -19.644571   3.813700 -16.080603 -10.494356
# 3   17.621333  -8.971605   9.613512  -5.000024  24.726601  22.760155
# 4  -16.564394   3.947515  12.408862 -11.836426  -2.538025  -1.542617
# 5  -12.006773  10.941001  14.695215  -9.179238  -2.214180   8.627802
#
#            x6         x7         x8         x9  ...    H39_31    H39_32  \
# id                                              ...
# 1   -2.303619  -5.881577  14.216969   8.264953  ...  0.283537  1.033067
# 2    0.498452  13.203046  22.474481  17.295968  ...  0.638254  1.183700
# 3    9.044282  11.059123  -5.573103   4.976253  ...  0.859743 -0.563825
# 4   11.329391   0.210301 -10.051592   9.573615  ...  0.664107 -1.207062
# 5   20.633262  11.669639  -1.136248  11.089953  ...  0.346159  0.450624
#
#       H39_33    H39_34    H39_35    H39_36    H39_37    H39_38    H39_39  \
# id
# 1  -0.873648  0.487017  2.125127 -0.349333  0.190956  1.383755  0.888078
# 2  -0.436492 -0.241744 -0.299361  0.506630  1.325080 -0.649825  0.417309
# 3   0.028349 -0.327561 -1.506802  0.066997  0.065092 -0.256844  0.424636
# 4  -0.083479  2.457111  1.199925 -1.754135  2.105366 -0.241441 -0.107689
# 5  -0.195505  0.055682 -1.246960 -0.347760 -0.144659 -1.614222 -1.028656
#
#       answer
# id
# 1   0.064764
# 2   0.063452
# 3   0.058519
# 4   0.068164
# 5   0.061577
#
# [5 rows x 1641 columns]

# %%
df_train = pd.get_dummies(df_train)
df_train = df_train.fillna(df_train.mean())
# df_train.head()
scale = StandardScaler()
Y = df_train['answer'].values
X = df_train.drop('answer',axis = 1)
print(X)
X = scale.fit_transform(X)
print(X)
# print(X_train[0])
# X = data.drop('answer',axis = 1)
# X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
# print(Y_train)
# Out:
# [[-1.0041244  -0.06518124 -0.47342855 ...  0.14036543  1.34776367
#    0.86717934]
#  [ 0.61730533 -0.16970592 -1.37509496 ...  1.29676228 -0.68512297
#    0.40637771]
#  [ 1.27399062 -0.61153394  0.77043417 ...  0.01202942 -0.29227599
#    0.41354983]
#  ...
#  [-0.71187199 -1.2845701  -0.2338865  ...  0.19011479 -0.28378899
#    1.7445021 ]
#  [-0.32587299  2.03068193 -0.07998967 ... -0.23406104 -0.70752549
#    1.15110619]
#  [ 0.98823557  0.64222358 -0.2987623  ... -0.25234916  0.11728569
#    0.10267023]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# first we fit the scaler on the training dataset
scaler.fit(X_train)

# then we call the transform method to scale both the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# a sample output
print(X_train)
print(X_train_scaled)
# Out:
#       id         x0         x1         x2         x3         x4         x5  \
# 440  441  21.375070 -18.309083 -24.975133   1.928087   0.900043 -21.474073
# 555  556   7.714742  11.066804   7.950365   7.585610  17.523262 -19.081938
# 707  708  12.898325   7.916939   1.080344  22.803495   8.326879   6.295867
# 268  269   0.306913   9.731864  -5.312390  -7.590166  -2.664624 -15.760080
