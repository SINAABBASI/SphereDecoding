# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler # Used for scaling of data
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from keras import metrics
import seaborn as sns
import matplotlib.pyplot as plt
from keras import backend as K
from keras.wrappers.scikit_learn import KerasRegressor
import seaborn as sns
import csv
# Out:
# Using TensorFlow backend.

# %%
dB = 16
df_train = pd.read_csv('./dataSets/Train_set'+str(dB)+'dB.csv', index_col=0)
df_train.head()
# Out:
#            x0        x1        x2         x3         x4        x5        x6  \
# id
# 0    0.385856  2.941212 -7.718302  -1.617972  -5.099098  8.106499 -0.083631
# 1   -6.384183  0.537708 -4.565977 -15.095605  -3.017754  0.731366  1.676142
# 2   -2.760693 -6.622539  7.138124   1.090823   7.945927  0.783751  3.290381
# 3  -10.498854 -5.105867  9.626430  13.090058   6.473866  2.830278  8.338596
# 4   -8.655726  2.094532 -2.626148  15.430766 -11.028822  1.831581  3.705835
#
#           x7         x8         x9  ...      H9_3      H9_4      H9_5  \
# id                                  ...
# 0   7.607127   6.152429   2.319884  ... -0.059566  0.461358  1.235065
# 1  -3.804663 -10.579322  -3.936332  ... -1.313080  0.662930 -0.929046
# 2  -0.010344  -0.621485  -4.562343  ...  0.382609  0.038581 -0.046272
# 3   5.124505   7.016561  -1.232316  ... -0.850369 -0.221611  1.417450
# 4   7.934533  -5.280342 -17.272616  ...  0.666046  0.383225  0.081390
#
#         H9_6      H9_7      H9_8      H9_9   answer0   answer1   answer2
# id
# 0   0.222012 -0.398682  0.476129  0.303785  2.779442  4.001936  4.298533
# 1  -0.738842  2.804688  0.406592  0.022099  2.233387  4.620470  4.988535
# 2  -0.952055 -0.429179 -2.115046  0.520427  3.876388  4.182068  4.412757
# 3  -1.143759 -0.579505  0.508113  0.124668  2.116346  4.943051  4.954038
# 4   0.436535  0.638094 -1.272633 -0.536718  2.625775  3.963458  4.588667
#
# [5 rows x 113 columns]

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
###Data is fully random so there is no corrolation

# %%
scale = StandardScaler()
cols = ['answer0','answer1','answer2']
Y = df_train[cols]
X = df_train.drop(['answer0','answer1','answer2'],axis = 1)

X = scale.fit_transform(X)
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# X_train = scale.fit_transform(X_train)
# X_test = scale.fit_transform(X_test)
# print(len(X[9999]))

# %%
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(8, activation='relu'))
model.add(Dense(3,activation='linear'))
# Compile model
#
model.compile(Adam(lr = 0.001), loss = 'mean_squared_error', metrics =[metrics.mae])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               14208
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 14,595
# Trainable params: 14,595
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

history = model.fit(X_train, Y_train, validation_split=0.2, epochs=150,batch_size=20,shuffle=True,verbose=0,callbacks=[earlystopper])
# Out:
# WARNING:tensorflow:From /home/sina/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 00013: early stopping

# %%
model.evaluate(X_test, Y_test)
# model.evaluate(X_train, Y_train)
# Out:
# 2000/2000 [==============================] - 0s 20us/step
# [0.40510334849357604, 0.509650707244873]

# %%
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
test_predictions = model.predict(X_train).flatten()

a = plt.axes(aspect='equal')
plt.scatter(Y_train, test_predictions)
plt.xlabel('True Values(Train)')
plt.ylabel('Predictions')
lims = [0,10]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)

# %%
test_predictions = model.predict(X_test).flatten()

b = plt.axes(aspect='equal')
plt.scatter(Y_test, test_predictions)
plt.xlabel('True Values(Test)')
plt.ylabel('Predictions')
lims = [0,10]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
test_predictions = model.predict(X_test)
X_test = scale.inverse_transform(X_test)
with open('./TestData'+str(dB)+'dB.csv',mode='w') as TD:
    wr = csv.writer(TD) #, quoting=csv.QUOTE_ALL)
    wr.writerows(X_test)
with open('./TestDataPrediction'+str(dB)+'dB.csv',mode='w') as TDP:
    wr = csv.writer(TDP) #, quoting=csv.QUOTE_ALL)
    wr.writerows(test_predictions)
